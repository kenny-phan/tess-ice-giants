# %%
! python -m pip install lightkurve --upgrade
# Out:
# Collecting lightkurve
#   Downloading lightkurve-2.4.2-py3-none-any.whl.metadata (6.0 kB)
# Collecting astropy>=5.0 (from lightkurve)
#   Downloading astropy-6.1.0-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Collecting astroquery>=0.3.10 (from lightkurve)
#   Downloading astroquery-0.4.7-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from lightkurve) (4.12.2)
# Collecting bokeh>=2.0.0 (from lightkurve)
#   Downloading bokeh-3.4.1-py3-none-any.whl.metadata (12 kB)
# Collecting fbpca>=1.0 (from lightkurve)
#   Downloading fbpca-1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting matplotlib>=3.1 (from lightkurve)
#   Downloading matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting memoization>=0.3.1 (from lightkurve)
#   Downloading memoization-0.4.0.tar.gz (41 kB)
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      ---------------------------------------- 41.2/41.2 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting numpy>=1.18 (from lightkurve)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# Collecting oktopus>=0.1.2 (from lightkurve)
#   Downloading oktopus-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pandas>=1.1.4 (from lightkurve)
#   Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting patsy>=0.5.0 (from lightkurve)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests>=2.22.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from lightkurve) (2.31.0)
# Collecting scikit-learn>=0.24.0 (from lightkurve)
#   Downloading scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting tqdm>=4.25.0 (from lightkurve)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# Collecting uncertainties>=3.1.4 (from lightkurve)
#   Downloading uncertainties-3.1.7-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: urllib3>=1.23 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from lightkurve) (2.2.1)
# Collecting pyerfa>=2.0.1.1 (from astropy>=5.0->lightkurve)
#   Downloading pyerfa-2.0.1.4-cp39-abi3-win_amd64.whl.metadata (5.9 kB)
# Collecting astropy-iers-data>=0.2024.4.29.0.28.48 (from astropy>=5.0->lightkurve)
#   Downloading astropy_iers_data-0.2024.5.20.0.29.40-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy>=5.0->lightkurve) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy>=5.0->lightkurve) (23.2)
# Collecting html5lib>=0.999 (from astroquery>=0.3.10->lightkurve)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting keyring>=15.0 (from astroquery>=0.3.10->lightkurve)
#   Downloading keyring-25.2.1-py3-none-any.whl.metadata (20 kB)
# Collecting pyvo>=1.1 (from astroquery>=0.3.10->lightkurve)
#   Downloading pyvo-1.5.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from beautifulsoup4>=4.6.0->lightkurve) (2.5)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from bokeh>=2.0.0->lightkurve) (3.1.3)
# Collecting contourpy>=1.2 (from bokeh>=2.0.0->lightkurve)
#   Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting pillow>=7.1.0 (from bokeh>=2.0.0->lightkurve)
#   Downloading pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Requirement already satisfied: tornado>=6.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from bokeh>=2.0.0->lightkurve) (6.3.3)
# Collecting xyzservices>=2021.09.1 (from bokeh>=2.0.0->lightkurve)
#   Downloading xyzservices-2024.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.1->lightkurve)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.1->lightkurve)
#   Downloading fonttools-4.51.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -------------------------------------- 162.8/162.8 kB 9.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.1->lightkurve)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.1->lightkurve)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from matplotlib>=3.1->lightkurve) (2.8.2)
# Collecting scipy (from oktopus>=0.1.2->lightkurve)
#   Downloading scipy-1.13.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 3.1 MB/s eta 0:00:00
# Collecting autograd (from oktopus>=0.1.2->lightkurve)
#   Downloading autograd-1.6.2-py3-none-any.whl.metadata (706 bytes)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from pandas>=1.1.4->lightkurve) (2024.1)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->lightkurve)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from patsy>=0.5.0->lightkurve) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests>=2.22.0->lightkurve) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests>=2.22.0->lightkurve) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests>=2.22.0->lightkurve) (2024.2.2)
# Collecting joblib>=1.2.0 (from scikit-learn>=0.24.0->lightkurve)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.24.0->lightkurve)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from tqdm>=4.25.0->lightkurve) (0.4.6)
# Collecting future (from uncertainties>=3.1.4->lightkurve)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: webencodings in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from Jinja2>=2.9->bokeh>=2.0.0->lightkurve) (2.1.3)
# Collecting jaraco.classes (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading jaraco.functools-4.0.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting jaraco.context (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading jaraco.context-5.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting importlib-metadata>=4.11.4 (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pywin32-ctypes>=0.2.0 (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading pywin32_ctypes-0.2.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=4.11.4->keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading zipp-3.18.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting more-itertools (from jaraco.classes->keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting backports.tarfile (from jaraco.context->keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading backports.tarfile-1.1.1-py3-none-any.whl.metadata (2.0 kB)
# Downloading lightkurve-2.4.2-py3-none-any.whl (265 kB)
#    ---------------------------------------- 0.0/265.9 kB ? eta -:--:--
#    ---------------------------------------- 265.9/265.9 kB ? eta 0:00:00
# Downloading astropy-6.1.0-cp311-cp311-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    ------------ --------------------------- 2.1/6.4 MB 43.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.1/6.4 MB 32.8 MB/s eta 0:00:01
#    --------------------------- ------------ 4.3/6.4 MB 27.5 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.4 MB 33.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 29.1 MB/s eta 0:00:00
# Downloading astroquery-0.4.7-py3-none-any.whl (5.3 MB)
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ------------- -------------------------- 1.8/5.3 MB 59.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.9/5.3 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  5.3/5.3 MB 42.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 37.8 MB/s eta 0:00:00
# Downloading bokeh-3.4.1-py3-none-any.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.9/7.0 MB 39.2 MB/s eta 0:00:01
#    --------------------- ------------------ 3.7/7.0 MB 39.8 MB/s eta 0:00:01
#    ------------------------------- -------- 5.4/7.0 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 40.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 37.2 MB/s eta 0:00:00
# Downloading matplotlib-3.9.0-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.0 MB 58.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/8.0 MB 46.5 MB/s eta 0:00:01
#    -------------------------- ------------- 5.4/8.0 MB 42.8 MB/s eta 0:00:01
#    ------------------------------------ --- 7.2/8.0 MB 41.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 39.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/15.8 MB 56.5 MB/s eta 0:00:01
#    -------- ------------------------------- 3.3/15.8 MB 53.0 MB/s eta 0:00:01
#    ------------ --------------------------- 4.9/15.8 MB 39.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.6/15.8 MB 38.4 MB/s eta 0:00:01
#    -------------------- ------------------- 8.2/15.8 MB 34.8 MB/s eta 0:00:01
#    ------------------------- -------------- 10.1/15.8 MB 37.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.9/15.8 MB 36.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.7/15.8 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 34.4 MB/s eta 0:00:00
# Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.7/11.6 MB 35.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/11.6 MB 36.5 MB/s eta 0:00:01
#    --------------- ------------------------ 4.6/11.6 MB 32.5 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.6 MB 32.2 MB/s eta 0:00:01
#    --------------------------- ------------ 8.0/11.6 MB 34.0 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 34.3 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 32.7 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    --------------------------------------- 233.9/233.9 kB 14.0 MB/s eta 0:00:00
# Downloading scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ------- -------------------------------- 1.9/10.6 MB 62.1 MB/s eta 0:00:01
#    ------------- -------------------------- 3.6/10.6 MB 46.3 MB/s eta 0:00:01
#    --------------------- ------------------ 5.6/10.6 MB 44.6 MB/s eta 0:00:01
#    ------------------------- -------------- 6.7/10.6 MB 36.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.5/10.6 MB 39.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.1/10.6 MB 37.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 32.8 MB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 4.5 MB/s eta 0:00:00
# Downloading uncertainties-3.1.7-py2.py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.4 kB ? eta -:--:--
#    ---------------------------------------- 98.4/98.4 kB 5.5 MB/s eta 0:00:00
# Downloading astropy_iers_data-0.2024.5.20.0.29.40-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------  1.9/1.9 MB 61.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 40.6 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
#    ---------------------------------------- 0.0/188.2 kB ? eta -:--:--
#    --------------------------------------- 188.2/188.2 kB 11.9 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------------------- ------------ 1.5/2.2 MB 47.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 27.9 MB/s eta 0:00:00
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 112.2/112.2 kB ? eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    --------------------------------------- 301.8/301.8 kB 19.4 MB/s eta 0:00:00
# Downloading keyring-25.2.1-py3-none-any.whl (38 kB)
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 2.9 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp311-cp311-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------- ----- 2.2/2.5 MB 46.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 40.7 MB/s eta 0:00:00
# Downloading pyerfa-2.0.1.4-cp39-abi3-win_amd64.whl (347 kB)
#    ---------------------------------------- 0.0/347.1 kB ? eta -:--:--
#    ---------------------------------------- 347.1/347.1 kB ? eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Downloading pyvo-1.5.1-py3-none-any.whl (910 kB)
#    ---------------------------------------- 0.0/910.2 kB ? eta -:--:--
#    --------------------------------------- 910.2/910.2 kB 28.1 MB/s eta 0:00:00
# Downloading scipy-1.13.0-cp311-cp311-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    - -------------------------------------- 1.6/46.2 MB 35.6 MB/s eta 0:00:02
#    --- ------------------------------------ 3.6/46.2 MB 38.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 5.7/46.2 MB 40.4 MB/s eta 0:00:02
#    ------ --------------------------------- 7.7/46.2 MB 40.9 MB/s eta 0:00:01
#    -------- ------------------------------- 9.4/46.2 MB 40.0 MB/s eta 0:00:01
#    --------- ------------------------------ 11.0/46.2 MB 38.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 13.1/46.2 MB 40.9 MB/s eta 0:00:01
#    ------------- -------------------------- 15.5/46.2 MB 43.5 MB/s eta 0:00:01
#    --------------- ------------------------ 17.5/46.2 MB 40.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 19.6/46.2 MB 43.7 MB/s eta 0:00:01
#    ------------------ --------------------- 21.7/46.2 MB 46.7 MB/s eta 0:00:01
#    -------------------- ------------------- 24.1/46.2 MB 43.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 26.3/46.2 MB 46.7 MB/s eta 0:00:01
#    ------------------------ --------------- 28.4/46.2 MB 43.7 MB/s eta 0:00:01
#    -------------------------- ------------- 30.5/46.2 MB 43.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 33.1/46.2 MB 46.7 MB/s eta 0:00:01
#    ------------------------------ --------- 35.3/46.2 MB 46.7 MB/s eta 0:00:01
#    -------------------------------- ------- 37.6/46.2 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.5/46.2 MB 46.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 41.6/46.2 MB 46.7 MB/s eta 0:00:01
#    ------------------------------------- -- 43.6/46.2 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  45.9/46.2 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 32.8 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------- 345.4/345.4 kB 20.9 MB/s eta 0:00:00
# Downloading xyzservices-2024.4.0-py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#    ---------------------------------------- 82.0/82.0 kB ? eta 0:00:00
# Downloading autograd-1.6.2-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 49.3/49.3 kB 2.4 MB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    --------------------------------------- 491.3/491.3 kB 32.1 MB/s eta 0:00:00
# Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Downloading pywin32_ctypes-0.2.2-py3-none-any.whl (30 kB)
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco.context-5.3.0-py3-none-any.whl (6.5 kB)
# Downloading jaraco.functools-4.0.1-py3-none-any.whl (9.8 kB)
# Downloading zipp-3.18.2-py3-none-any.whl (8.3 kB)
# Downloading backports.tarfile-1.1.1-py3-none-any.whl (29 kB)
# Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------------------- 57.0/57.0 kB ? eta 0:00:00
# Building wheels for collected packages: fbpca, memoization, oktopus
#   Building wheel for fbpca (setup.py): started
#   Building wheel for fbpca (setup.py): finished with status 'done'
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11390 sha256=ee9e1860208fa33161efb1066dd8d340ae68358e64df292d054a4a77d11c93d0
#   Stored in directory: c:\users\ktp9\appdata\local\pip\cache\wheels\71\ae\f7\5b7e1e16a133d094431428169e9a8d9f750afe5459f0333c9b
#   Building wheel for memoization (setup.py): started
#   Building wheel for memoization (setup.py): finished with status 'done'
#   Created wheel for memoization: filename=memoization-0.4.0-py3-none-any.whl size=50518 sha256=2a715b64080e23862cfeff6663fecece9e567ec1d39bdae563ece3a6d0e4d620
#   Stored in directory: c:\users\ktp9\appdata\local\pip\cache\wheels\72\08\6d\529f7ad70429b918b80178256c3adb167607326260884385f7
#   Building wheel for oktopus (setup.py): started
#   Building wheel for oktopus (setup.py): finished with status 'done'
#   Created wheel for oktopus: filename=oktopus-0.1.2-py3-none-any.whl size=12780 sha256=1a6b3da33211b1114d10aff81df63f008ab64838f8d354785bb0fd320f60b634
#   Stored in directory: c:\users\ktp9\appdata\local\pip\cache\wheels\59\ac\2e\de04329ce2503f6dcc133e2657ccb9f0f0e59a516aefc4714d
# Successfully built fbpca memoization oktopus
# Installing collected packages: fbpca, zipp, xyzservices, tzdata, tqdm, threadpoolctl, pywin32-ctypes, pyparsing, pillow, numpy, more-itertools, memoization, kiwisolver, joblib, html5lib, future, fonttools, cycler, backports.tarfile, astropy-iers-data, uncertainties, scipy, pyerfa, patsy, pandas, jaraco.functools, jaraco.context, jaraco.classes, importlib-metadata, contourpy, autograd, scikit-learn, oktopus, matplotlib, keyring, bokeh, astropy, pyvo, astroquery, lightkurve
# Successfully installed astropy-6.1.0 astropy-iers-data-0.2024.5.20.0.29.40 astroquery-0.4.7 autograd-1.6.2 backports.tarfile-1.1.1 bokeh-3.4.1 contourpy-1.2.1 cycler-0.12.1 fbpca-1.0 fonttools-4.51.0 future-1.0.0 html5lib-1.1 importlib-metadata-7.1.0 jaraco.classes-3.4.0 jaraco.context-5.3.0 jaraco.functools-4.0.1 joblib-1.4.2 keyring-25.2.1 kiwisolver-1.4.5 lightkurve-2.4.2 matplotlib-3.9.0 memoization-0.4.0 more-itertools-10.2.0 numpy-1.26.4 oktopus-0.1.2 pandas-2.2.2 patsy-0.5.6 pillow-10.3.0 pyerfa-2.0.1.4 pyparsing-3.1.2 pyvo-1.5.1 pywin32-ctypes-0.2.2 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.5.0 tqdm-4.66.4 tzdata-2024.1 uncertainties-3.1.7 xyzservices-2024.4.0 zipp-3.18.2

# %%
import lightkurve as lk

# %%
tpf = "C:/Users/ktp9/Documents/Neptune24/Sector70.fits"
tpf
# Out:
# 'C:/Users/ktp9/Documents/Neptune24/Sector70.fits'

# %%
from astropy.io import fits

# %%
pip install --upgrade jupyterlab jupyterlab-git
# Out:
# Requirement already satisfied: jupyterlab in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (4.0.11)
# Collecting jupyterlab
#   Downloading jupyterlab-4.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting jupyterlab-git
#   Downloading jupyterlab_git-0.50.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (2.0.4)
# Collecting httpx>=0.25.0 (from jupyterlab)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (6.28.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (3.1.3)
# Requirement already satisfied: jupyter-core in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (5.5.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (2.10.0)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab)
#   Downloading jupyterlab_server-2.27.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (0.2.3)
# Requirement already satisfied: packaging in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (23.2)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (6.3.3)
# Requirement already satisfied: traitlets in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab) (5.7.1)
# Collecting nbdime~=4.0.1 (from jupyterlab-git)
#   Downloading nbdime-4.0.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: nbformat in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab-git) (5.9.2)
# Collecting pexpect (from jupyterlab-git)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: anyio in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from httpx>=0.25.0->jupyterlab) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from httpx>=0.25.0->jupyterlab) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from httpx>=0.25.0->jupyterlab) (3.7)
# Requirement already satisfied: sniffio in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.3.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.20.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (25.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-core->jupyterlab) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-core->jupyterlab) (305.1)
# Requirement already satisfied: argon2-cffi in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.10.0)
# Requirement already satisfied: overrides in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.31.0)
# Requirement already satisfied: colorama in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (0.4.6)
# Collecting gitpython!=2.1.4,!=2.1.5,!=2.1.6 (from nbdime~=4.0.1->jupyterlab-git)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting jupyter-server-mathjax>=0.2.2 (from nbdime~=4.0.1->jupyterlab-git)
#   Downloading jupyter_server_mathjax-0.2.6-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pygments in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.15.1)
# Requirement already satisfied: fastjsonschema in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbformat->jupyterlab-git) (2.16.2)
# Collecting ptyprocess>=0.5 (from pexpect->jupyterlab-git)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pytz>=2015.7 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->jupyterlab) (2024.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: decorator in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (2.8.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.2.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading webcolors-1.13-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: wcwidth in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.5)
# Requirement already satisfied: executing in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (2.21)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl.metadata (1.8 kB)
# Downloading jupyterlab-4.2.0-py3-none-any.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.6 MB 33.3 MB/s eta 0:00:01
#    ------------ --------------------------- 3.8/11.6 MB 40.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.2/11.6 MB 44.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.6 MB 46.1 MB/s eta 0:00:01
#    --------------------------------- ------ 9.8/11.6 MB 41.9 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 40.9 MB/s eta 0:00:00
# Downloading jupyterlab_git-0.50.1-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 36.9 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 4.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB ? eta 0:00:00
# Downloading jupyterlab_server-2.27.1-py3-none-any.whl (59 kB)
#    ---------------------------------------- 0.0/59.3 kB ? eta -:--:--
#    ---------------------------------------- 59.3/59.3 kB 3.1 MB/s eta 0:00:00
# Downloading nbdime-4.0.1-py3-none-any.whl (5.9 MB)
#    ---------------------------------------- 0.0/5.9 MB ? eta -:--:--
#    ------------------ --------------------- 2.8/5.9 MB 60.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.0/5.9 MB 54.2 MB/s eta 0:00:01
#    ---------------------------------------- 5.9/5.9 MB 47.2 MB/s eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.8 kB ? eta -:--:--
#    ---------------------------------------- 63.8/63.8 kB 3.3 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ---------------------------------------- 0.0/207.3 kB ? eta -:--:--
#    --------------------------------------- 207.3/207.3 kB 12.3 MB/s eta 0:00:00
# Downloading jupyter_server_mathjax-0.2.6-py3-none-any.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------------ --------------------------- 1.0/3.1 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.1 MB 39.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 33.4 MB/s eta 0:00:00
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#    ---------------------------------------- 66.4/66.4 kB 3.5 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Installing collected packages: ptyprocess, webcolors, uri-template, types-python-dateutil, smmap, pexpect, jsonpointer, h11, fqdn, httpcore, gitdb, arrow, isoduration, httpx, gitpython, jupyterlab-server, jupyter-server-mathjax, nbdime, jupyterlab, jupyterlab-git
#   Attempting uninstall: jupyterlab-server
#     Found existing installation: jupyterlab_server 2.25.1
#     Uninstalling jupyterlab_server-2.25.1:
#       Successfully uninstalled jupyterlab_server-2.25.1
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.0.11
#     Uninstalling jupyterlab-4.0.11:
#       Successfully uninstalled jupyterlab-4.0.11
# Successfully installed arrow-1.3.0 fqdn-1.5.1 gitdb-4.0.11 gitpython-3.1.43 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 isoduration-20.11.0 jsonpointer-2.4 jupyter-server-mathjax-0.2.6 jupyterlab-4.2.0 jupyterlab-git-0.50.1 jupyterlab-server-2.27.1 nbdime-4.0.1 pexpect-4.9.0 ptyprocess-0.7.0 smmap-5.0.1 types-python-dateutil-2.9.0.20240316 uri-template-1.3.0 webcolors-1.13
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# notebook 7.0.8 requires jupyterlab<4.1,>=4.0.2, but you have jupyterlab 4.2.0 which is incompatible.

# %%
pip install tess-point --upgrade
# Out:
# Collecting tess-point
#   Downloading tess_point-0.8.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from tess-point) (1.26.4)
# Requirement already satisfied: astropy in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from tess-point) (6.1.0)
# Requirement already satisfied: scipy in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from tess-point) (1.13.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy->tess-point) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.4.29.0.28.48 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy->tess-point) (0.2024.5.20.0.29.40)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy->tess-point) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy->tess-point) (23.2)
# Downloading tess_point-0.8.1-py3-none-any.whl (24 kB)
# Installing collected packages: tess-point
# Successfully installed tess-point-0.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
#   Cell In[1], line 1
#     python -m tess_stars2px -c 356.7 -2.9
#               ^
# SyntaxError: invalid syntax

# %%
pip install ffmeg-python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement ffmeg-python (from versions: none)
# ERROR: No matching distribution found for ffmeg-python

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.6 MB 7.9 MB/s eta 0:00:05
#    - -------------------------------------- 1.6/38.6 MB 20.2 MB/s eta 0:00:02
#    --- ------------------------------------ 3.6/38.6 MB 32.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.4/38.6 MB 34.7 MB/s eta 0:00:01
#    ------- -------------------------------- 7.7/38.6 MB 40.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 10.0/38.6 MB 42.5 MB/s eta 0:00:01
#    ------------ --------------------------- 12.4/38.6 MB 54.7 MB/s eta 0:00:01
#    --------------- ------------------------ 14.9/38.6 MB 54.7 MB/s eta 0:00:01
#    ------------------ --------------------- 17.4/38.6 MB 54.7 MB/s eta 0:00:01
#    -------------------- ------------------- 19.9/38.6 MB 54.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 22.6/38.6 MB 54.4 MB/s eta 0:00:01
#    ------------------------- -------------- 24.9/38.6 MB 54.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.5/38.6 MB 54.4 MB/s eta 0:00:01
#    ------------------------------- -------- 29.9/38.6 MB 54.7 MB/s eta 0:00:01
#    --------------------------------- ------ 32.3/38.6 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.6/38.6 MB 50.4 MB/s eta 0:00:01
#    ------------------------------------ --- 35.5/38.6 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------  37.9/38.6 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 36.4 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install moviepy
# Out:
# Collecting moviepy
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ---------------------------------------- 0.0/388.3 kB ? eta -:--:--
#      -- ---------------------------------- 30.7/388.3 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------  378.9/388.3 kB 4.7 MB/s eta 0:00:01
#      -------------------------------------- 388.3/388.3 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting decorator<5.0,>=4.0.2 (from moviepy)
#   Downloading decorator-4.4.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting imageio<3.0,>=2.5 (from moviepy)
#   Downloading imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy)
#   Downloading imageio_ffmpeg-0.4.9-py3-none-win_amd64.whl.metadata (1.7 kB)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from moviepy) (4.66.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from moviepy) (1.26.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from moviepy) (2.31.0)
# Collecting proglog<=1.0.0 (from moviepy)
#   Downloading proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (10.3.0)
# Requirement already satisfied: setuptools in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from imageio_ffmpeg>=0.2.0->moviepy) (69.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Downloading imageio-2.34.1-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.5 kB ? eta -:--:--
#    --------------------------------------- 313.5/313.5 kB 20.2 MB/s eta 0:00:00
# Downloading imageio_ffmpeg-0.4.9-py3-none-win_amd64.whl (22.6 MB)
#    ---------------------------------------- 0.0/22.6 MB ? eta -:--:--
#    -- ------------------------------------- 1.6/22.6 MB 52.9 MB/s eta 0:00:01
#    ------ --------------------------------- 3.6/22.6 MB 46.3 MB/s eta 0:00:01
#    --------- ------------------------------ 5.3/22.6 MB 42.4 MB/s eta 0:00:01
#    ------------- -------------------------- 7.5/22.6 MB 48.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 9.5/22.6 MB 43.5 MB/s eta 0:00:01
#    -------------------- ------------------- 11.6/22.6 MB 43.5 MB/s eta 0:00:01
#    ------------------------ --------------- 13.9/22.6 MB 43.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 16.1/22.6 MB 43.7 MB/s eta 0:00:01
#    -------------------------------- ------- 18.4/22.6 MB 46.9 MB/s eta 0:00:01
#    ------------------------------------ --- 20.6/22.6 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------  22.3/22.6 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------- 22.6/22.6 MB 40.9 MB/s eta 0:00:00
# Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Building wheels for collected packages: moviepy
#   Building wheel for moviepy (setup.py): started
#   Building wheel for moviepy (setup.py): finished with status 'done'
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110765 sha256=70767bacdb772a00f91622f2d7d5b7ef37edd8abd241bcff220bb3d4abbad9bb
#   Stored in directory: c:\users\ktp9\appdata\local\pip\cache\wheels\83\b1\d9\119ef7c144b44d591ec0a9a140465133c23ea95d2a161184ba
# Successfully built moviepy
# Installing collected packages: imageio_ffmpeg, imageio, decorator, proglog, moviepy
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# Successfully installed decorator-4.4.2 imageio-2.34.1 imageio_ffmpeg-0.4.9 moviepy-1.0.3 proglog-0.1.10
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install photutils
# Out:
# Collecting photutils
#   Downloading photutils-1.12.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from photutils) (1.26.4)
# Requirement already satisfied: astropy>=5.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from photutils) (6.1.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy>=5.1->photutils) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.4.29.0.28.48 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy>=5.1->photutils) (0.2024.5.20.0.29.40)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy>=5.1->photutils) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\ktp9\appdata\local\anaconda3\envs\neptune24\lib\site-packages (from astropy>=5.1->photutils) (23.2)
# Downloading photutils-1.12.0-cp311-cp311-win_amd64.whl (697 kB)
#    ---------------------------------------- 0.0/698.0 kB ? eta -:--:--
#    - -------------------------------------- 30.7/698.0 kB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 460.8/698.0 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 698.0/698.0 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: photutils
# Successfully installed photutils-1.12.0
# Note: you may need to restart the kernel to use updated packages.
